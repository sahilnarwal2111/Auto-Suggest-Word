# %%
import pandas as pd
import numpy as np
import textdistance
import re
from collections import Counter

# %%
word = []
with open('autocorrect book.txt', 'r', encoding='utf-8') as f:
    data = f.read()
    data = data.lower()
    words = re.findall('\w+', data)
    words += words


print(words[0:10])
# Out:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'moby', 'or', 'the', 'whale', 'by']

# %% [markdown]
# # make vocabulary

# %%
len(words)
# Out:
# 445146

# %%
V = set(words)
V
print(V)
print(len(V))
# Out:
# {'recent', 'tierce', '4', 'slanting', 'braves', 'thunderbolts', 'loosed', 'gentle', 'voyager', 'endwise', 'revelry', 'impenitent', 'tantamount', 'fattening', 'recruit', 'illinois', 'sixteen', 'crackled', 'chair', 'glass', 'thwack', 'titanic', 'entranced', '_grampus_', 'inestimable', 'clews', 'opening', 'seclusion', 'circulating', 'optically', 'contributory', '75', 'unsavory', 'practically', 'causing', 'breast', 'focus', 'lunar', 'cylindrically', 'interrupt', 'haze', 'sunny', 'hyperborean', 'unattended', 'voyagers', 'resolutely', 'cruiser', 'unprofitable', 'flag', 'ahab', 'lye', 'tickled', 'cottage', 'particulars', 'premises', 'stig', 'waved', 'feathery', 'sciences', 'unnecessary', 'entertaining', 'omnipotent', 'whaleman', 'idleness', 'giddy', 'cullest', 'rearing', 'unrustlingly', 'wade', 'dramatist', 'oxygenated', 'sinecure', 'road', 'swooped', 'consisting', 'sentimental', 'accelerate', 'breakers', 'escaped', 'amidst', 'paid_', 'manliest', 'hated', 'hence', 'gauntleted', 'retrace', 'exegetists', 'yawing', 'forbids', 'desperadoes', 'fencing', 'grandissimus', 'outcries', 'punish', 'indicating', 'peacefully', 'floor', 'gap', 'spent', 'cheeked', 'sternly', 'terraces', 'lusty', 'observations', 'employs', 'hadst', 'tap', 'missionaries', 'chain', 'spade', 'repeating', 'thunders', 'shows', 'subalterns', 'mince', 'enactment', 'indifference', 'transactions', 'hags', 'judgment', 'concentrating', 'partaking', 'beds', 'distinguishing', 'discharge', 'lounging', 'vindictive', 'transformed', 'marshal', 'depths', 'delirious', 'forged', 'time', 'unsheathes', 'footpath', 'dinnerless', 'houseless', 'painters', 'greenhorn', 'wall', 'successively', '_stowe', 'becomes', 'charges', 'gleam', 'property', 'indefinitely', 'eels', 'sinecures', 'armed', 'elucidate', 'omnipresent', 'bustles', 'tough', 'information', 'redeemed', 'entreaties', 'law', 'spires', '1668', 'human', 'stubbing', 'oaks', 'espying', 'extinction', 'wading', 'sign', 'sprang', 'brighggians', 'images', 'colnett', 'riotous', 'intermixed', 'baby', 'roundly', 'lave', 'cardinals', 'japan', 'infidelities', 'seasoned', 'jails', 'charities', 'rigger', 'shout', 'rough', 'wilted', 'kinsmen', 'diligence', 'decapitating', 'sides', 'disinfecting', 'sentry', 'overswarm', 'garden', 'injury', 'federal', 'story', 'happens', 'tree', 'oozy', 'write', 'overhung', 'becket', 'statutory', 'produces', '_captain', 'tusk', 'replenish', 'savesoul', 'hopefulness', 'hardihood', 'supposition', 'flutterings', 'security', 'impairs', 'brush', 'designated', 'operations', 'warringly', 'gateway', 'negligence', 'quarter', 'employed', 'baptismal', 'wafted', 'midwifery', 'slipperiness', 'eccentric', 'adhering', 'creations', 'persist', 'gallows', 'thumb', 'inboard', 'headsmen', 'poles', 'strivest', 'boldness', 'toothless', 'frequently', 'likened', 'susceptible', 'overdoing', 'three', 'hove', 'consorted', 'suds', 'ceremonial', 'tahitan', 'witch', 'monsoons', 'germain', 'regular', 'favour', 'previous', 'tragically', 'charmingly', 'ago', 'ringing', 'exasperated', 'virus', 'greenland', 'ferule', 'disinterred', 'heroically', '_grand', 'cakes', 'groves', 'attaining', 'wondrous', 'read', 'raises', 'musky', 'flitting', 'pitiful', 'phantoms', 'wrists', 'needle', 'reminiscences', 'questionably', 'impulsively', 'antichronical', 'choice', 'formerly', 'os', 'accident', 'floes', 'lurches', '114', 'ladies', 'erie', 'guides', 'divined', 'cherishing', 'carving', 'impaling', 'japonicas', 'middling', 'card', 'bigness', 'accuracy', 'villainous', 'state_', 'piloted', 'jeopardy', 'liberties', 'past', 'grateful', 'better', 'yarn', 'tableau', 'methods', 'prince', 'barbed', 'impediments', 'esquimaux', 'upward', 'elephanta', 'en', 'intermission', 'scramble', 'conceal', '_i', 'purposes', 'disinterested', 'recluseness', 'wallow', 'buttered', 'mint', 'medallions', 'alluringly', 'inseparable', '_spanish_', 'paddle', 'napoleon', 'bounced', 'truth', 'earthquake', 'machine', 'prayed', 'detects', 'pour', 'oft', 'presentations', 'graceful', 'finite', 'coiling', ...
# 17646

# %%
len(V)
# Out:
# 17646

# %% [markdown]
# # build the frequency of those words

# %%
words_freq_dict = {}
words_freq_dict = Counter(words)

# %%
words_freq_dict.most_common()[0:10]
# Out:
# [('the', 29406),
#  ('of', 13484),
#  ('and', 13034),
#  ('a', 9598),
#  ('to', 9414),
#  ('in', 8476),
#  ('that', 6162),
#  ('it', 5068),
#  ('his', 5060),
#  ('i', 4240)]

# %% [markdown]
# # Relative Frequency of words
# Now we want to get the probability of occurrence of each word, this equals the relative frequencies of the words:

# %% [markdown]
# The formula used to calculate the probability of a word in the provided code is:
#
# Probability(word) = Frequency(word) / Total count of all words

# %%
Total = sum(words_freq_dict.values())
probs = {}

for k in words_freq_dict.keys():
    probs[k] = words_freq_dict[k] / Total

# %%
probs
# Out:
# {'the': 0.06605922551252848,
#  'project': 0.0004088546229776298,
#  'gutenberg': 0.00042233334681205715,
#  'ebook': 4.492907944809119e-05,
#  'of': 0.03029118536390308,
#  'moby': 0.0004043617150328207,
#  'or': 0.0035808476320128677,
#  'whale': 0.0055262767721152165,
#  'by': 0.005490333508556744,
#  'herman': 1.7971631779236475e-05,
#  'melville': 1.7971631779236475e-05,
#  'this': 0.006465294532580322,
#  'is': 0.007867081811360766,
#  'for': 0.007386340661266191,
#  'use': 0.00022015248929564682,
#  'anyone': 2.6957447668854714e-05,
#  'anywhere': 7.18865271169459e-05,
#  'at': 0.0059980321063201735,
#  'no': 0.0026687873192166164,
#  'cost': 1.7971631779236475e-05,
#  'and': 0.029280281076321028,
#  'with': 0.007947954154367332,
#  'almost': 0.0008851028651273964,
#  'restrictions': 8.985815889618237e-06,
#  'whatsoever': 3.1450355613663834e-05,
#  'you': 0.004304205811127136,
#  'may': 0.0011456915259263254,
#  'copy': 8.536525095137325e-05,
#  'it': 0.011385028732146307,
#  'give': 0.0004043617150328207,
#  'away': 0.0008356808777344961,
#  're': 8.087234300656413e-05,
#  'under': 0.000566106401045949,
#  'terms': 0.0001482659621787009,
#  'license': 8.087234300656413e-05,
#  'included': 6.290071122732767e-05,
#  'online': 1.7971631779236475e-05,
#  'www': 2.6957447668854714e-05,
#  'org': 5.8407803282518544e-05,
#  'title': 3.594326355847295e-05,
#  'author': 4.0436171503282066e-05,
#  'release': 4.492907944809119e-06,
#  'date': 1.7971631779236475e-05,
#  'december': 2.2464539724045594e-05,
#  '25': 1.7971631779236475e-05,
#  '2008': 4.492907944809119e-06,
#  '2701': 1.7971631779236475e-05,
#  'last': 0.001249028408656935,
#  'updated': 8.985815889618237e-06,
#  '3': 7.18865271169459e-05,
#  '2017': 4.492907944809119e-06,
#  'language': 3.1450355613663834e-05,
#  'english': 0.00022015248929564682,
#  'character': 6.739361917213678e-05,
#  'set': 0.0003818971753087751,
#  'encoding': 4.492907944809119e-06,
#  'utf': 4.492907944809119e-06,
#  '8': 3.1450355613663834e-05,
#  'start': 0.0001662375939579374,
#  'produced': 4.0436171503282066e-05,
#  'daniel': 1.7971631779236475e-05,
#  'lazarus': 3.1450355613663834e-05,
#  'jonesey': 8.985815889618237e-06,
#  'david': 8.985815889618237e-06,
#  'widger': 8.985815889618237e-06,
#  'contents': 3.594326355847295e-05,
#  'etymology': 8.985815889618237e-06,
#  'extracts': 3.1450355613663834e-05,
#  'supplied': 5.8407803282518544e-05,
#  'a': 0.021561465227138962,
#  'sub': 4.0436171503282066e-05,
#  'librarian': 8.985815889618237e-06,
#  'chapter': 0.0013838156470012085,
#  '1': 0.00022015248929564682,
#  'loomings': 8.985815889618237e-06,
#  '2': 3.1450355613663834e-05,
#  'carpet': 4.0436171503282066e-05,
#  'bag': 0.00010333688273060973,
#  'spouter': 3.594326355847295e-05,
#  'inn': 7.637943506175502e-05,
#  '4': 4.0436171503282066e-05,
#  'counterpane': 3.594326355847295e-05,
#  '5': 3.1450355613663834e-05,
#  'breakfast': 6.739361917213678e-05,
#  '6': 1.7971631779236475e-05,
#  'street': 6.290071122732767e-05,
#  '7': 3.1450355613663834e-05,
#  'chapel': 4.9421987392900305e-05,
#  'pulpit': 7.637943506175502e-05,
#  '9': 2.2464539724045594e-05,
#  'sermon': 2.2464539724045594e-05,
#  '10': 2.2464539724045594e-05,
#  'bosom': 4.0436171503282066e-05,
#  'friend': 0.00012130851450984621,
#  '11': 8.985815889618237e-06,
#  'nightgown': 8.985815889618237e-06,
#  '12': 8.985815889618237e-06,
#  'biographical': 8.985815889618237e-06,
#  '13': 1.7971631779236475e-05,
#  'wheelbarrow': 1.7971631779236475e-05,
#  '14': 8.985815889618237e-06,
#  'nantucket': 0.00042233334681205715,
#  '15': 8.985815889618237e-06,
#  'chowder': 4.492907944809119e-05,
#  '16': 8.985815889618237e-06,
#  'ship': 0.002331819223355933,
#  '17': 8.985815889618237e-06,
#  'ramadan': 5.391489533770943e-05,
#  '18': 8.985815889618237e-06,
#  'his': 0.01136705710036707,
#  'mark': 0.00025160284490931067,
#  '19': 8.985815889618237e-06,
#  'prophet': 7.637943506175502e-05,
#  '20': 2.2464539724045594e-05,
#  'all': 0.00693704986678528,
#  'astir': 1.7971631779236475e-05,
#  '21': 8.985815889618237e-06,
#  'going': 0.0004043617150328207,
#  'aboard': 9.884397478580061e-05,
#  '22': 8.985815889618237e-06,
#  'merry': 6.290071122732767e-05,
#  'christmas': 2.6957447668854714e-05,
#  '23': 8.985815889618237e-06,
#  'lee': 9.43510668409915e-05,
#  'shore': 0.00011681560656503709,
#  '24': 8.985815889618237e-06,
#  'advocate': 1.7971631779236475e-05,
#  'postscript': 8.985815889618237e-06,
#  '26': 8.985815889618237e-06,
#  'knights': 2.6957447668854714e-05,
#  'squires': 1.7971631779236475e-05,
#  '27': 8.985815889618237e-06,
#  '28': 8.985815889618237e-06,
#  'ahab': 0.0023003688677422688,
#  '29': 8.985815889618237e-06,
#  'enter': 4.9421987392900305e-05,
#  'to': 0.021148117696216523,
#  'him': 0.004784946961221712,
#  'stubb': 0.0011636631577055618,
#  '30': 1.7971631779236475e-05,
#  'pipe': 0.000188702133681983,
#  '31': 8.985815889618237e-06,
#  'queen': 8.087234300656413e-05,
#  'mab': 8.985815889618237e-06,
#  '32': 8.985815889618237e-06,
#  'cetology': 4.9421987392900305e-05,
#  '33': 8.985815889618237e-06,
#  'specksnyder': 1.7971631779236475e-05,
#  '34': 8.985815889618237e-06,
#  'cabin': 0.00039088299119839333,
#  'table': 0.0001707305019027465,
#  '35': 8.985815889618237e-06,
#  'mast': 0.0005840780328251854,
#  'head': 0.0015635319647935733,
#  '36': 8.985815889618237e-06,
#  'quarter': 0.0002156595813508377,
#  'deck': 0.0008940886810170146,
#  '37': 8.985815889618237e-06,
#  'sunset': 4.492907944809119e-05,
#  '38': 8.985815889618237e-06,
#  'dusk': 1.3478723834427357e-05,
#  '39': 8.985815889618237e-06,
#  'first': 0.0010738049988093794,
#  'night': 0.000682922007610986,
#  'watch': 0.00027406738463335627,
#  '40': 1.3478723834427357e-05,
#  'midnight': 0.00013478723834427355,
#  'forecastle': 0.0001707305019027465,
#  '41': 8.985815889618237e-06,
#  '42': 8.985815889618237e-06,
#  'whiteness': 0.00012580142245465533,
#  '43': 8.985815889618237e-06,
#  'hark': 7.637943506175502e-05,
#  '44': 8.985815889618237e-06,
#  'chart': 3.594326355847295e-05,
#  '45': 1.3478723834427357e-05,
#  'affidavit': 1.3478723834427357e-05,
#  '46': 8.985815889618237e-06,
#  'surmises': 1.7971631779236475e-05,
#  '47': 8.985815889618237e-06,
#  'mat': 5.8407803282518544e-05,
#  'maker': 2.2464539724045594e-05,
#  '48': 8.985815889618237e-06,
#  'lowering': 8.536525095137325e-05,
#  '49': 8.985815889618237e-06,
#  'hyena': 1.7971631779236475e-05,
#  '50': 1.3478723834427357e-05,
#  's': 0.008172599551607786,
#  'boat': 0.0015006312535662456,
#  'crew': 0.0006335000202180857,
#  'fedallah': 0.00012580142245465533,
#  '51': 8.985815889618237e-06,
#  'spirit': 8.536525095137325e-05,
#  'spout': 0.00027406738463335627,
#  '52': 8.985815889618237e-06,
#  'albatross': 4.492907944809119e-05,
#  '53': 8.985815889618237e-06,
#  'gam': 2.6957447668854714e-05,
#  '54': 8.985815889618237e-06,
#  'town': 0.00016174468601312826,
#  'ho': 0.0001437730542338918,
#  'story': 0.00022913830518526507,
#  '55': 8.985815889618237e-06,
#  'monstrous': 5.391489533770943e-05,
#  'pictures': 8.536525095137325e-05,
#  'whales': 0.0012175780530432711,
#  '56': 8.985815889618237e-06,
#  'less': 0.00024261702901969242,
#  'erroneous': 8.985815889618237e-06,
#  'true': 0.00039537589914320244,
#  'whaling': 0.0005930638487148036,
#  'scenes': 5.391489533770943e-05,
#  '57': 8.985815889618237e-06,
#  'in': 0.019040943870101044,
#  'paint': 3.1450355613663834e-05,
#  'teeth': 0.00022464539724045593,
#  'wood': 0.0001662375939579374,
#  'sheet': 4.0436171503282066e-05,
#  'iron': 0.00039537589914320244,
#  'stone': 8.985815889618238e-05,
#  'mountains': 6.290071122732767e-05,
#  'stars': 6.290071122732767e-05,
#  '58': 8.985815889618237e-06,
#  'brit': 4.0436171503282066e-05,
#  '59': 8.985815889618237e-06,
#  'squid': 3.594326355847295e-05,
#  '60': 1.7971631779236475e-05,
#  'line': 0.000718865271169459,
#  '61': 8.985815889618237e-06,
#  'kills': 1.3478723834427357e-05,
#  '62': 8.985815889618237e-06,
#  'dart': 0.00011681560656503709,
#  '63': 8.985815889618237e-06,
#  'crotch': 4.9421987392900305e-05,
#  '64': 1.3478723834427357e-05,
#  'supper': 0.0001392801462890827,
#  '65': 8.985815889618237e-06,
#  'as': 0.007871574719305576,
#  'dish': 4.9421987392900305e-05,
#  '66': 8.985815889618237e-06,
#  'shark': 0.0001392801462890827,
#  'massacre': 1.3478723834427357e-05,
#  '67': 8.985815889618237e-06,
#  'cutting': 0.0001707305019027465,
#  '68': 8.985815889618237e-06,
#  'blanket': 6.290071122732767e-05,
#  '69': 8.985815889618237e-06,
#  'funeral': 2.6957447668854714e-05,
#  '70': 8.985815889618237e-06,
#  'sphynx': 1.3478723834427357e-05,
#  '71': 8.985815889618237e-06,
#  'jeroboam': 4.9421987392900305e-05,
#  '72': 1.3478723834427357e-05,
#  'monkey': 7.637943506175502e-05,
#  'rope': 0.0002695744766885471,
#  '73': 8.985815889618237e-06,
#  'flask': 0.0004897269659841939,
#  'kill': 0.00015275887012351004,
#  'right': 0.0006964007314454134,
#  'then': 0.0028305320052297448,
#  'have': 0.003477510749282258,
#  'talk': 0.00011681560656503709,
#  'over': 0.0018420922573717388,
#  '74': 8.985815889618237e-06,
#  'sperm': 0.0010872837226438066,
#  'contrasted': 1.7971631779236475e-05,
#  'view': 0.00022464539724045593,
#  '75': 8.985815889618237e-06,
#  '76': 8.985815889618237e-06,
#  'battering': 3.1450355613663834e-05,
#  'ram': 3.594326355847295e-05,
#  '77': 8.985815889618237e-06,
#  'great': 0.0013793227390563995,
#  'heidelburgh': 4.0436171503282066e-05,
#  'tun': 6.739361917213678e-05,
#  '78': 8.985815889618237e-06,
#  'cistern': 2.2464539724045594e-05,
#  'buckets': 2.6957447668854714e-05,
#  '79': 8.985815889618237e-06,
#  'prairie': 5.8407803282518544e-05,
#  '80': 8.985815889618237e-06,
#  'nut': 2.2464539724045594e-05,
#  '81': 8.985815889618237e-06,
#  'pequod': 0.000795244706231214,
#  'meets': 6.290071122732767e-05,
#  'virgin': 5.391489533770943e-05,
#  '82': 8.985815889618237e-06,
#  'honor': 0.00011232269862022797,
#  'glory': 8.536525095137325e-05,
#  '83': 8.985815889618237e-06,
#  'jonah': 0.0003818971753087751,
#  'historically': 8.985815889618237e-06,
#  'regarded': 0.00011232269862022797,
#  '84': 8.985815889618237e-06,
#  'pitchpoling': 3.1450355613663834e-05,
#  '85': 8.985815889618237e-06,
#  'fountain': 4.492907944809119e-05,
#  '86': 8.985815889618237e-06,
#  'tail': 0.0003639255435295386,
#  '87': 8.985815889618237e-06,
#  'grand': 0.00024261702901969242,
#  'armada': 8.985815889618237e-06,
#  '88': 8.985815889618237e-06,
#  'schools': 4.0436171503282066e-05,
#  'schoolmasters': 1.3478723834427357e-05,
#  '89': 8.985815889618237e-06,
#  'fast': 0.0002875461084677836,
#  'fish': 0.0007593014426727411,
#  'loose': 0.0001662375939579374,
#  '90': 1.7971631779236475e-05,
#  'heads': 0.00039088299119839333,
#  'tails': 3.594326355847295e-05,
#  '91': 8.985815889618237e-06,
#  'rose': 0.00015725177806831915,
#  'bud': 2.6957447668854714e-05,
#  '92': 8.985815889618237e-06,
#  'ambergris': 6.290071122732767e-05,
#  '93': 8.985815889618237e-06,
#  'castaway': 2.2464539724045594e-05,
#  '94': 8.985815889618237e-06,
#  'squeeze': 4.492907944809119e-05,
#  'hand': 0.0009659752081339606,
#  '95': 8.985815889618237e-06,
#  'cassock': 1.3478723834427357e-05,
#  '96': 8.985815889618237e-06,
#  'try': 0.00024710993696450156,
#  'works': 0.0002875461084677836,
#  '97': 8.985815889618237e-06,
#  'lamp': 0.00013478723834427355,
#  '98': 8.985815889618237e-06,
#  'stowing': 1.3478723834427357e-05,
#  'down': 0.001702812111082656,
#  'clearing': 2.6957447668854714e-05,
#  'up': 0.0023632695789695965,
#  '99': 8.985815889618237e-06,
#  'doubloon': 9.43510668409915e-05,
#  '100': 1.7971631779236475e-05,
#  'leg': 0.0004088546229776298,
#  'arm': 0.0004043617150328207,
#  '101': 8.985815889618237e-06,
#  'decanter': 1.3478723834427357e-05,
#  '102': 8.985815889618237e-06,
#  'bower': 1.7971631779236475e-05,
#  'arsacides': 1.7971631779236475e-05,
#  '103': 8.985815889618237e-06,
#  'measurement': 1.7971631779236475e-05,
#  'skeleton': 0.00015725177806831915,
#  '104': 8.985815889618237e-06,
#  'fossil': 2.2464539724045594e-05,
#  '105': 8.985815889618237e-06,
#  'does': 0.00044030497859129364,
#  'magnitude': 0.00010333688273060973,
#  'diminish': 2.2464539724045594e-05,
#  'will': 0.0017926702699788384,
#  'he': 0.00851855346335809,
#  'perish': 2.2464539724045594e-05,
#  '106': 8.985815889618237e-06,
#  '107': 8.985815889618237e-06,
#  'carpenter': 0.00022464539724045593,
#  '108': 8.985815889618237e-06,
#  '109': 8.985815889618237e-06,
#  'starbuck': 0.0008940886810170146,
#  '110': 8.985815889618237e-06,
#  'queequeg': 0.001136705710036707,
#  'coffin': 0.00023812412107488329,
#  '111': 8.985815889618237e-06,
#  'pacific': 0.00015725177806831915,
#  '112': 8.985815889618237e-06,
#  'blacksmith': 9.884397478580061e-05,
#  '113': 8.985815889618237e-06,
#  'forge': 5.8407803282518544e-05,
#  '114': 8.985815889618237e-06,
#  'gilder': 8.985815889618237e-06,
#  '115': 8.985815889618237e-06,
#  'bachelor': 4.0436171503282066e-05,
#  '116': 8.985815889618237e-06,
#  'dying': 6.739361917213678e-05,
#  '117': 8.985815889618237e-06,
#  '118': 8.985815889618237e-06,
#  'quadrant': 4.0436171503282066e-05,
#  '119': 8.985815889618237e-06,
#  'candles': 4.492907944809119e-05,
#  '120': 8.985815889618237e-06,
#  'towards': 0.0005166844136530487,
#  'end': 0.00046276951831533924,
#  '121': 8.985815889618237e-06,
#  'bulwarks': 0.0001707305019027465,
#  '122': 8.985815889618237e-06,
#  'aloft': 0.0002830532005229745,
#  'thunder': 0.0001437730542338918,
#  'lightning': 0.00012580142245465533,
#  '123': 8.985815889618237e-06,
#  'musket': 4.0436171503282066e-05,
#  '124': 8.985815889618237e-06,
#  'needle': 5.391489533770943e-05,
#  '125': 8.985815889618237e-06,
#  'log': 0.00010333688273060973,
#  '126': 8.985815889618237e-06,
#  'life': 0.0007862588903415958,
#  'buoy': 6.290071122732767e-05,
#  '127': 8.985815889618237e-06,
#  '128': 8.985815889618237e-06,
#  'rachel': 3.1450355613663834e-05,
#  '129': 8.985815889618237e-06,
#  '130': 8.985815889618237e-06,
#  'hat': 0.00018420922573717386,
#  '131': 8.985815889618237e-06,
#  'delight': 8.536525095137325e-05,
#  '132': 8.985815889618237e-06,
#  'symphony': 8.985815889618237e-06,
#  '133': 8.985815889618237e-06,
#  'chase': 0.0002785602925781654,
#  'day': 0.0008042305221208323,
#  '134': 8.985815889618237e-06,
#  'second': 0.0002785602925781654,
#  '135': 8.985815889618237e-06,
#  'third': 0.00015275887012351004,
#  'epilogue': 8.985815889618237e-06,
#  'original': 0.00010333688273060973,
#  'transcriber': 4.492907944809119e-06,
#  'notes': 1.7971631779236475e-05,
#  'text': 2.6957447668854714e-05,
#  'combination': 8.985815889618237e-06,
#  'etexts': 4.492907944809119e-06,
#  'one': 0.004151446941003626,
#  'from': 0.004960170371069267,
#  'now': 0.0035314256446199676,
#  'defunct': 8.985815889618237e-06,
#  'eris': 4.492907944809119e-06,
#  'virginia': 2.6957447668854714e-05,
#  'tech': 8.985815889618237e-06,
#  'archives': 4.492907944809119e-06,
#  'proofreaders': 4.492907944809119e-06,
#  'version': 2.6957447668854714e-05,
#  'are': 0.0027766171098920355,
#  'indebted': 8.985815889618237e-06,
#  'university': 4.492907944809119e-06,
#  'adelaide': 4.492907944809119e-06,
#  'library': 1.3478723834427357e-05,
#  'preserving': 1.7971631779236475e-05,
#  'resulting': 1.3478723834427357e-05,
#  'etext': 4.492907944809119e-06,
#  'was': 0.0073953264771558095,
#  'compared': 4.0436171503282066e-05,
#  'public': 6.739361917213678e-05,
#  'domain': 4.0436171503282066e-05,
#  'hard': 0.000377404267363966,
#  'late': 0.00013478723834427355,
#  'consumptive': 4.492907944809119e-06,
#  'usher': 8.985815889618237e-06,
#  'grammar': 8.985815889618237e-06,
#  'school': 4.492907944809119e-05,
#  'pale': 8.536525095137325e-05,
#  'threadbare': 4.492907944809119e-06,
#  'coat': 0.00012580142245465533,
#  'heart': 0.0004088546229776298,
#  'body': 0.0004942198739290031,
#  'brain': 0.0001662375939579374,
#  'i': 0.009524964842995332,
#  'see': 0.0012355496848225076,
#  'ever': 0.0009255390366306785,
#  'dusting': 8.985815889618237e-06,
#  'old': 0.002030794391053722,
#  'lexicons': 4.492907944809119e-06,
#  'grammars': 8.985815889618237e-06,
#  'queer': 0.00019768794957160122,
#  'handkerchief': 2.2464539724045594e-05,
#  'mockingly': 4.492907944809119e-06,
#  'embellished': 1.3478723834427357e-05,
#  'gay': 9.43510668409915e-05,
#  'flags': 4.492907944809119e-06,
#  'known': 0.0003594326355847295,
#  'nations': 5.391489533770943e-05,
#  'world': 0.0007907517982864049,
#  'loved': 1.3478723834427357e-05,
#  'dust': 4.492907944809119e-05,
#  'somehow': 0.00019768794957160122,
#  'mildly': 4.492907944809119e-05,
#  'reminded': 1.7971631779236475e-05,
#  'mortality': 4.492907944809119e-06,
#  'while': 0.0011052553544230433,
#  'take': 0.0006155283884388493,
#  'others': 0.00017971631779236476,
#  'teach': 2.2464539724045594e-05,
#  'them': 0.0021296383658395224,
#  'what': 0.0027721242019472262,
#  'name': 0.0003145035561366383,
#  'be': 0.004775961145332093,
#  'called': 0.0005211773215978578,
#  'our': 0.000948003576354724,
#  'tongue': 4.9421987392900305e-05,
#  'leaving': 0.0001707305019027465,
#  'out': 0.0024126915663624966,
#  'through': 0.001055833367030143,
#  'ignorance': 4.9421987392900305e-05,
#  'letter': 7.18865271169459e-05,
#  'h': 1.3478723834427357e-05,
#  'which': 0.0029428547038499726,
#  'alone': 0.000188702133681983,
#  'maketh': 2.2464539724045594e-05,
#  'signification': 4.492907944809119e-06,
#  'word': 0.00034595391175030213,
#  'deliver': 1.3478723834427357e-05,
#  'that': 0.013842649377956895,
#  'not': 0.005270181019261097,
#  '_hackluyt': 4.492907944809119e-06,
#  '_': 0.00022015248929564682,
#  'sw': 4.492907944809119e-06,
#  'dan': 3.1450355613663834e-05,
#  '_hval_': 4.492907944809119e-06,
#  'animal': 7.18865271169459e-05,
#  'named': 5.391489533770943e-05,
#  'roundness': 4.492907944809119e-06,
#  'rolling': 0.00015725177806831915,
#  '_hvalt_': 4.492907944809119e-06,
#  'arched': 4.9421987392900305e-05,
#  'vaulted': 8.985815889618237e-06,
#  '_webster': 4.492907944809119e-06,
#  'dictionary': 1.7971631779236475e-05,
#  'more': 0.002277904328018223,
#  'immediately': 7.637943506175502e-05,
#  'dut': 4.492907944809119e-06,
#  'ger': 4.492907944809119e-06,
#  '_wallen_': 4.492907944809119e-06,
#  '_walw': 4.492907944809119e-06,
#  'ian_': 4.492907944809119e-06,
#  'roll': 8.087234300656413e-05,
#  'wallow': 1.3478723834427357e-05,
#  '_richardson': 4.492907944809119e-06,
#  'חו': 4.492907944809119e-06,
#  '_hebrew_': 4.492907944809119e-06,
#  'ϰητος': 4.492907944809119e-06,
#  '_greek_': 4.492907944809119e-06,
#  'cetus': 1.3478723834427357e-05,
#  '_latin_': 4.492907944809119e-06,
#  'whœl': 4.492907944809119e-06,
#  '_anglo': 4.492907944809119e-06,
#  'saxon_': 4.492907944809119e-06,
#  'hvalt': 4.492907944809119e-06,
#  '_danish_': 4.492907944809119e-06,
#  'wal': 4.492907944809119e-06,
#  '_dutch_': 4.492907944809119e-06,
#  'hwal': 4.492907944809119e-06,
#  '_swedish_': 4.492907944809119e-06,
#  '_icelandic_': 4.492907944809119e-06,
#  '_english_': 4.492907944809119e-06,
#  'ballena': 4.492907944809119e-06,
#  '_spanish_': 4.492907944809119e-06,
#  'pekee': 4.492907944809119e-06,
#  'nuee': 1.7971631779236475e-05,
#  '_fegee_': 4.492907944809119e-06,
#  'pehee': 4.492907944809119e-06,
#  '_erromangoan_': 4.492907944809119e-06,
#  'seen': 0.0007413298108935046,
#  'mere': 0.000188702133681983,
#  'painstaking': 4.492907944809119e-06,
#  'burrower': 4.492907944809119e-06,
#  'grub': 8.985815889618237e-06,
#  'worm': 2.2464539724045594e-05,
#  'poor': 0.0005121915057082396,
#  'devil': 0.00024710993696450156,
#  'appears': 3.594326355847295e-05,
#  'gone': 0.000265081568743738,
#  'long': 0.0014916454376766274,
#  'vaticans': 4.492907944809119e-06,
#  'stalls': 4.492907944809119e-06,
#  'earth': 0.00020667376546121947,
#  'picking': 1.7971631779236475e-05,
#  'whatever': 0.00020667376546121947,
#  'random': 2.2464539724045594e-05,
#  'allusions': 3.1450355613663834e-05,
#  'could': 0.0009749610240235788,
#  'anyways': 8.985815889618237e-06,
#  'find': 0.00025160284490931067,
#  'any': 0.0016354184919105193,
#  'book': 0.0002695744766885471,
#  'sacred': 4.492907944809119e-05,
#  'profane': 2.2464539724045594e-05,
#  'therefore': 0.000301024832302211,
#  'must': 0.0013164220278290718,
#  'every': 0.0010423546431957155,
#  'case': 0.00032348937202625653,
#  'least': 0.000341461003805493,
#  'higgledy': 4.492907944809119e-06,
#  'piggledy': 4.492907944809119e-06,
#  'statements': 2.2464539724045594e-05,
#  'however': 0.0004313191627016754,
#  'authentic': 1.3478723834427357e-05,
#  'these': 0.001819627717647693,
#  'veritable': 1.7971631779236475e-05,
#  'gospel': 8.985815889618237e-06,
#  'far': 0.0007413298108935046,
#  'touching': 0.00020667376546121947,
#  'ancient': 0.00012580142245465533,
#  'authors': 1.7971631779236475e-05,
#  'generally': 0.0001392801462890827,
#  'well': 0.0010333688273060973,
#  'poets': 1.3478723834427357e-05,
#  'here': 0.001437730542338918,
#  'appearing': 1.7971631779236475e-05,
#  'solely': 2.6957447668854714e-05,
#  'valuable': 4.9421987392900305e-05,
#  'entertaining': 8.985815889618237e-06,
#  'affording': 8.985815889618237e-06,
#  'glancing': 6.290071122732767e-05,
#  'bird': 7.637943506175502e-05,
#  'eye': 0.00039537589914320244,
#  'has': 0.0013164220278290718,
#  'been': 0.0018645567970957844,
#  'promiscuously': 4.492907944809119e-06,
#  'said': 0.0013703369231667813,
#  'thought': 0.0006739361917213678,
#  'fancied': 4.0436171503282066e-05,
#  'sung': 8.985815889618237e-06,
#  'leviathan': 0.00042682625475686626,
#  'many': 0.000754808534727932,
#  'generations': 3.594326355847295e-05,
#  'including': 7.18865271169459e-05,
#  'own': 0.0009210461286858694,
#  'so': 0.00478943986916652,
#  'fare': 4.492907944809119e-05,
#  'thee': 0.0005885709407699945,
#  'whose': 0.00039088299119839333,
#  'commentator': 4.492907944809119e-06,
#  'am': 0.0004043617150328207,
#  'thou': 0.0012175780530432711,
#  'belongest': 4.492907944809119e-06,
#  'hopeless': 3.594326355847295e-05,
#  'sallow': 4.492907944809119e-06,
#  'tribe': 4.0436171503282066e-05,
#  'wine': 5.391489533770943e-05,
#  'warm': 0.00010782979067541886,
#  'whom': 0.00020218085751641036,
#  'even': 0.00086713123334816,
#  'sherry': 4.492907944809119e-06,
#  'would': 0.0019409362321575394,
#  'too': 0.000831187969789687,
#  'rosy': 8.985815889618237e-06,
#  'strong': 0.00016174468601312826,
#  'but': 0.008190571183387023,
#  'sometimes': 0.00039088299119839333,
#  'loves': 4.492907944809119e-06,
#  'sit': 6.739361917213678e-05,
#  'feel': 0.0002560957528541198,
#  'devilish': 4.0436171503282066e-05,
#  'grow': 0.00010782979067541886,
#  'convivial': 1.7971631779236475e-05,
#  'upon': 0.0025519717126515793,
#  'tears': 2.6957447668854714e-05,
#  'say': 0.001096269538533425,
#  'bluntly': 4.492907944809119e-06,
#  'full': 0.0006110354804940402,
#  'eyes': 0.0007008936393902226,
#  'empty': 9.884397478580061e-05,
#  'glasses': 4.492907944809119e-05,
#  'altogether': 0.00013029433039946444,
#  'unpleasant': 1.3478723834427357e-05,
#  'sadness': 8.985815889618237e-06,
#  'subs': 4.492907944809119e-06,
#  'how': 0.0011591702497607526,
#  'much': 0.0010064113796372427,
#  'pains': 6.739361917213678e-05,
#  'ye': 0.002120652549949904,
#  'please': 7.18865271169459e-05,
#  'shall': 0.00043581207064648453,
#  'go': 0.00086713123334816,
#  'thankless': 4.492907944809119e-06,
#  'clear': 0.00018420922573717386,
#  'hampton': 4.492907944809119e-06,
#  'court': 8.985815889618237e-06,
#  'tuileries': 1.3478723834427357e-05,
#  'gulp': 8.985815889618237e-06,
#  'your': 0.0011546773418159436,
#  'hie': 4.492907944809119e-06,
#  'royal': 0.00012580142245465533,
#  'hearts': 0.00013029433039946444,
#  'friends': 7.637943506175502e-05,
#  'who': 0.0016444043078001375,
#  'before': 0.0013523652913875449,
#  'seven': 7.18865271169459e-05,
#  'storied': 1.7971631779236475e-05,
#  'heavens': 7.637943506175502e-05,
#  'making': 0.00020667376546121947,
#  'refugees': 4.492907944809119e-06,
#  'pampered': 4.492907944809119e-06,
#  'gabriel': 8.985815889618238e-05,
#  'michael': 1.3478723834427357e-05,
#  'raphael': 4.492907944809119e-06,
#  'against': 0.0006065425725492311,
#  'coming': 0.00024261702901969242,
#  'strike': 0.0001437730542338918,
#  'splintered': 3.1450355613663834e-05,
#  'together': 0.0002875461084677836,
#  'there': 0.003886365372259888,
#  'unsplinterable': 4.492907944809119e-06,
#  'god': 0.0006874149155557951,
#  'created': 4.0436171503282066e-05,
#  '_genesis_': 4.492907944809119e-06,
#  'path': 4.492907944809119e-05,
#  'shine': 1.3478723834427357e-05,
#  'after': 0.0012130851450984621,
#  'think': 0.0005481347692667125,
#  'deep': 0.0003145035561366383,
#  'hoary': 8.985815889618237e-06,
#  '_job_': 4.492907944809119e-06,
#  'lord': 0.0002920390164125927,
#  'had': 0.0034999752890063035,
#  'prepared': 5.391489533770943e-05,
#  'swallow': 4.9421987392900305e-05,
#  '_jonah_': 4.492907944809119e-06,
#  'ships': 0.00039537589914320244,
#  'hast': 0.00013029433039946444,
#  'made': 0.0007997376141760231,
#  'play': 0.00013029433039946444,
#  'therein': 2.6957447668854714e-05,
#  '_psalms_': 4.492907944809119e-06,
#  'sore': 1.3478723834427357e-05,
#  'sword': 0.00011232269862022797,
#  'punish': 4.492907944809119e-06,
#  'piercing': 1.7971631779236475e-05,
#  'serpent': 1.7971631779236475e-05,
#  'crooked': 3.594326355847295e-05,
#  'slay': 1.7971631779236475e-05,
#  'dragon': 2.6957447668854714e-05,
#  'sea': 0.002044273114888149,
#  '_isaiah_': 4.492907944809119e-06,
#  'thing': 0.0008446666936241143,
#  'soever': 4.492907944809119e-06,
#  'besides': 0.00022464539724045593,
#  'cometh': 4.492907944809119e-06,
#  'within': 0.00037291135941915684,
#  'chaos': 1.7971631779236475e-05,
#  'monster': 0.00022015248929564682,
#  'mouth': 0.00027406738463335627,
#  'beast': 1.7971631779236475e-05,
#  'goes': 0.00024710993696450156,
#  'incontinently': 4.492907944809119e-06,
#  'foul': 4.9421987392900305e-05,
#  'perisheth': 4.492907944809119e-06,
#  'bottomless': 3.1450355613663834e-05,
#  'gulf': 2.6957447668854714e-05,
#  'paunch': 8.985815889618237e-06,
#  '_holland': 8.985815889618237e-06,
#  'plutarch': 4.492907944809119e-06,
#  'morals_': 4.492907944809119e-06,
#  'indian': 0.0002560957528541198,
#  'breedeth': 4.492907944809119e-06,
#  'most': 0.0012804787642705989,
#  'biggest': 8.985815889618237e-06,
#  'fishes': 2.2464539724045594e-05,
#  'among': 0.0007503156267831228,
#  'whirlpooles': 4.492907944809119e-06,
#  'balaene': 4.492907944809119e-06,
#  'length': 0.0003504468196951113,
#  'four': 0.0003324751879158748,
#  'acres': 1.3478723834427357e-05,
#  'arpens': 4.492907944809119e-06,
#  'land': 0.0003594326355847295,
#  'pliny_': 4.492907944809119e-06,
#  'scarcely': 4.0436171503282066e-05,
#  'we': 0.0021071738261154768,
#  'proceeded': 2.6957447668854714e-05,
#  'two': 0.0013299007516634992,
#  'days': 0.0003863900832535842,
#  'on': 0.0048208902247801845,
#  'when': 0.002727195122499135,
#  'about': 0.0014287447264492998,
#  'sunrise': 4.9421987392900305e-05,
#  'other': 0.0019319504162679212,
#  'monsters': 4.0436171503282066e-05,
#  'appeared': 4.492907944809119e-05,
#  'former': 8.985815889618238e-05,
#  'size': 5.391489533770943e-05,
#  'came': 0.0005840780328251854,
#  'us': 0.0010288759193612881,
#  'open': 0.000341461003805493,
#  'mouthed': 2.2464539724045594e-05,
#  'raising': 2.2464539724045594e-05,
#  'waves': 0.0002156595813508377,
#  'sides': 0.00012580142245465533,
#  'beating': 4.9421987392900305e-05,
#  'into': 0.0023497908551351693,
#  'foam': 8.536525095137325e-05,
#  '_tooke': 4.492907944809119e-06,
#  'lucian_': 4.492907944809119e-06,
#  '_the': 5.391489533770943e-05,
#  'history_': 4.492907944809119e-06,
#  'visited': 3.1450355613663834e-05,
#  'country': 0.00012130851450984621,
#  'also': 0.00041784043886724804,
#  'catching': 3.1450355613663834e-05,
#  'horse': 0.00012130851450984621,
#  'bones': 0.00022015248929564682,
#  'very': 0.0014512092661733455,
#  'value': 2.6957447668854714e-05,
#  'their': 0.0027856029257816535,
#  'brought': 0.0001707305019027465,
#  'some': 0.0027811100178368447,
#  'king': 0.0002830532005229745,
#  'best': 0.0002965319243574018,
#  'were': 0.003068656126304628,
#  'catched': 4.492907944809119e-06,
#  'forty': 0.0001482659621787009,
#  'eight': 0.00012130851450984621,
#  'fifty': 0.0001482659621787009,
#  'yards': 0.00012130851450984621,
#  'six': 0.0001392801462890827,
#  'killed': 0.00015725177806831915,
#  'sixty': 7.637943506175502e-05,
#  '_other': 4.492907944809119e-06,
#  'verbal': 8.985815889618237e-06,
#  'narrative': 4.0436171503282066e-05,
#  'taken': 0.00022913830518526507,
#  'alfred': 8.985815889618237e-06,
#  'd': 0.0003369680958606839,
#  '890': 4.492907944809119e-06,
#  'whereas': 8.087234300656413e-05,
#  'things': 0.000602049664604422,
#  'whether': 0.0004088546229776298,
#  'vessel': 0.00024710993696450156,
#  'dreadful': 2.6957447668854714e-05,
#  'lost': 0.00021116667340602858,
#  'swallowed': 5.8407803282518544e-05,
#  'gudgeon': 4.492907944809119e-06,
#  'retires': 4.492907944809119e-06,
#  'security': 1.3478723834427357e-05,
#  'sleeps': 3.1450355613663834e-05,
#  'montaigne': 4.492907944809119e-06,
#  '_apology': 4.492907944809119e-06,
#  'raimond': 4.492907944809119e-06,
#  'sebond_': 4.492907944809119e-06,
#  'let': 0.0007098794552798408,
#  'fly': 6.290071122732767e-05,
#  'nick': 8.985815889618237e-06,
#  'me': 0.0028260390972849356,
#  'if': 0.0022509468803493687,
#  'described': 4.0436171503282066e-05,
#  'noble': 0.00019768794957160122,
#  'moses': 8.985815889618237e-06,
#  'patient': 2.6957447668854714e-05,
#  'job': 6.290071122732767e-05,
#  '_rabelais_': 4.492907944809119e-06,
#  'liver': 1.7971631779236475e-05,
#  'cartloads': 4.492907944809119e-06,
#  '_stowe': 4.492907944809119e-06,
#  'annals_': 4.492907944809119e-06,
#  'seas': 0.00039088299119839333,
#  'seethe': 1.3478723834427357e-05,
#  'like': 0.0029069114402914997,
#  'boiling': 6.739361917213678e-05,
#  'pan': 2.2464539724045594e-05,
#  '_lord': 4.492907944809119e-06,
#  'bacon': 4.492907944809119e-06,
#  'psalms_': 4.492907944809119e-06,
#  'bulk': 0.0001437730542338918,
#  'ork': 4.492907944809119e-06,
#  'received': 0.0001392801462890827,
#  'nothing': 0.0005166844136530487,
#  'certain': 0.0004088546229776298,
#  'they': 0.003001262507132491,
#  'exceeding': 5.391489533770943e-05,
#  'fat': 6.290071122732767e-05,
#  'insomuch': 8.985815889618237e-06,
#  'an': 0.0026957447668854713,
#  'incredible': 4.0436171503282066e-05,
#  'quantity': 5.8407803282518544e-05,
#  'oil': 0.0004043617150328207,
#  'extracted': 2.2464539724045594e-05,
#  '_ibid_': 1.3478723834427357e-05,
#  '_history': 4.492907944809119e-06,
#  'death_': 4.492907944809119e-06,
#  'sovereignest': 4.492907944809119e-06,
#  'parmacetti': 1.3478723834427357e-05,
#  'inward': 2.2464539724045594e-05,
#  'bruise': 4.492907944809119e-06,
#  '_king': 4.492907944809119e-06,
#  'henry_': 4.492907944809119e-06,
#  '_hamlet_': 4.492907944809119e-06,
#  'secure': 5.8407803282518544e-05,
#  'skill': 4.492907944809119e-05,
#  'leach': 4.492907944809119e-06,
#  'art': 0.00018420922573717386,
#  'mote': 4.492907944809119e-06,
#  'availle': 4.492907944809119e-06,
#  'returne': 4.492907944809119e-06,
#  'againe': 4.492907944809119e-06,
#  'wound': 7.637943506175502e-05,
#  'worker': 4.492907944809119e-06,
#  'lowly': 3.594326355847295e-05,
#  'dinting': 4.492907944809119e-06,
#  'breast': 3.1450355613663834e-05,
#  'bred': 4.0436171503282066e-05,
#  'restless': 1.7971631779236475e-05,
#  'paine': 4.492907944809119e-06,
#  'wounded': 4.0436171503282066e-05,
#  'flies': 3.1450355613663834e-05,
#  'thro': 4.492907944809119e-06,
#  'maine': 4.492907944809119e-06,
#  'faerie': 4.492907944809119e-06,
#  'queen_': 4.492907944809119e-06,
#  'immense': 7.18865271169459e-05,
#  'motion': 7.637943506175502e-05,
#  'vast': 0.0003279822799710657,
#  'bodies': 4.0436171503282066e-05,
#  'can': 0.0011097482623678523,
#  'peaceful': 2.6957447668854714e-05,
#  'calm': 0.00018420922573717386,
#  'trouble': 4.9421987392900305e-05,
#  'ocean': 0.0003549397276399204,
#  'till': 0.0005526276772115216,
#  'boil': 8.985815889618237e-06,
#  '_sir': 1.7971631779236475e-05,
#  'william': 1.7971631779236475e-05,
#  'davenant': 4.492907944809119e-06,
#  'preface': 4.492907944809119e-06,
#  'gondibert_': 4.492907944809119e-06,
#  'spermacetti': 1.3478723834427357e-05,
#  'men': 0.001096269538533425,
#  'might': 0.0008222021539000688,
#  'justly': 1.3478723834427357e-05,
#  'doubt': 0.0001437730542338918,
#  'since': 0.0002920390164125927,
#  'learned': 0.00011232269862022797,
#  'hosmannus': 4.492907944809119e-06,
#  'work': 0.0004897269659841939,
#  'thirty': 0.00012580142245465533,
#  'years': 0.00043581207064648453,
#  'saith': 2.2464539724045594e-05,
#  'plainly': 0.00017522340984755565,
#  '_nescio': 4.492907944809119e-06,
#  'quid': 8.985815889618237e-06,
#  'sit_': 4.492907944809119e-06,
#  't': 0.0013029433039946445,
#  'browne': 2.6957447668854714e-05,
#  'sperma': 1.3478723834427357e-05,
#  'ceti': 1.3478723834427357e-05,
#  'vide': 4.492907944809119e-06,
#  'v': 3.1450355613663834e-05,
#  'e': 0.00023363121313007418,
#  'spencer': 4.492907944809119e-06,
#  'talus': 4.492907944809119e-06,
#  'modern': 8.087234300656413e-05,
#  'flail': 4.492907944809119e-06,
#  'threatens': 4.492907944809119e-06,
#  'ruin': 2.2464539724045594e-05,
#  'ponderous': 5.8407803282518544e-05,
#  'fixed': 0.0001707305019027465,
#  'jav': 4.492907944809119e-06,
#  'lins': 4.492907944809119e-06,
#  'side': 0.0009345248525202967,
#  'wears': 3.1450355613663834e-05,
#  'back': 0.0007233581791142681,
#  'grove': 1.3478723834427357e-05,
#  'pikes': 8.985815889618237e-06,
#  '_waller': 4.492907944809119e-06,
#  'battle': 0.0001392801462890827,
#  'summer': 7.18865271169459e-05,
#  'islands_': 4.492907944809119e-06,
#  'commonwealth': 4.492907944809119e-06,
#  'state': 0.0001482659621787009,
#  'latin': 1.7971631779236475e-05,
#  'civitas': 4.492907944809119e-06,
#  'artificial': 2.2464539724045594e-05,
#  'man': 0.0023677624869144057,
#  '_opening': 4.492907944809119e-06,
#  'sentence': 1.3478723834427357e-05,
#  'hobbes': 4.492907944809119e-06,
#  'leviathan_': 4.492907944809119e-06,
#  'silly': 2.2464539724045594e-05,
#  'mansoul': 4.492907944809119e-06,
#  'without': 0.0007368369029486955,
#  'chewing': 4.492907944809119e-06,
#  'sprat': 4.492907944809119e-06,
#  '_pilgrim': 4.492907944809119e-06,
#  'progress_': 4.492907944809119e-06,
#  'hugest': 1.7971631779236475e-05,
#  'swim': 9.43510668409915e-05,
#  'stream': 4.9421987392900305e-05,
#  '_paradise': 4.492907944809119e-06,
#  'lost_': 4.492907944809119e-06,
#  'living': 0.0003279822799710657,
#  'creatures': 0.00015275887012351004,
#  'stretched': 4.492907944809119e-05,
#  'promontory': 2.2464539724045594e-05,
#  'swims': 3.594326355847295e-05,
#  'seems': 0.00039088299119839333,
#  'moving': 6.739361917213678e-05,
#  'gills': 1.7971631779236475e-05,
#  'draws': 4.492907944809119e-06,
#  'breath': 8.087234300656413e-05,
#  'spouts': 7.18865271169459e-05,
#  'mighty': 0.00021116667340602858,
#  'water': 0.0008536525095137325,
#  'swimming': 0.00013478723834427355,
#  '_fuller': 4.492907944809119e-06,
#  'holy': 9.43510668409915e-05,
#  'state_': 4.492907944809119e-06,
#  'close': 0.00025160284490931067,
#  'behind': 0.00022464539724045593,
#  'lie': 0.00012130851450984621,
#  ...}

# %% [markdown]
# # Finding Similar Words
# Now we will sort similar words according to the Jaccard distance by calculating the 2 grams Q of the words. Next, we will return the 5 most similar words ordered by similarity and probability:
#
#
# The Jaccard distance measures the dissimilarity between two sets by comparing their intersection and union

# %%
def autocorrect(word):
    word = word.lower()
    if word in V:
        return('Your word seems to be correct', word)
    else:
        similarities = [1-(textdistance.Jaccard(qval=2).distance(v,word))  for v in words_freq_dict.keys()]
        df = pd.DataFrame.from_dict(probs, orient='index').reset_index()
        df = df.rename(columns={'index':'Word',0:'Prob'})
        df['Similarity'] = similarities
        output = df.sort_values(['Similarity','Prob'],ascending=False).head(8)
        return(output)
autocorrect("helo")
# Out:
#           Word      Prob  Similarity
# 2968      help  0.000184    0.500000
# 3030      held  0.000166    0.500000
# 4472      helm  0.000157    0.500000
# 1652      hell  0.000076    0.500000
# 7988      heel  0.000036    0.500000
# 374   bachelor  0.000040    0.428571
# 6120     below  0.000234    0.400000
# 1559     wheel  0.000027    0.400000
